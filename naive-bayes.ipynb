# %% [markdown]
# # Import Library dan load data

# %%
import pandas as pd

data = pd.read_csv('dataset/data-review-aplikasi-bukalapak.csv')
data.shape
# Out:
# (303, 3)

# %%
data.head(5)
# Out:
#    ID                                             Ulasan    Kelas
# 0   1                          belanja murah & mudah say  Positif
# 1   2  belanja produk digital disini aja gaesss pulsa...  Positif
# 2   3  Sering belanja di bukalapak. Nyaman murah terp...  Positif
# 3   4                   ecommerce yang mudah utk belanja  Positif
# 4   5  Sangat membantu hidup saya..  mudah2n bukalapa...  Positif

# %%
data.tail(5)
# Out:
#       ID                                             Ulasan    Kelas
# 298  299  Sejauh ini gak ada kendala dan masalah. Serta ...  Positif
# 299  300  Luar biasa. Baru kali ini saya mendapat keuntu...  Positif
# 300  301            jangan sampe ngga belanja pokoknya hehe  Positif
# 301  302                   sudah ngga lemot bagus bukalapak  Positif
# 302  303  Saya sangat nyaman belanja di Bukalapak, Harga...  Positif

# %%
data.sample(5)
# Out:
#       ID                                             Ulasan    Kelas
# 45    46                                  Santai dan Akurat  Positif
# 101  102  Kecewa dengan bukalapak duit sdh dibalikin kar...  Negatif
# 193  194  udah lah mending pindah ke yag lain aja males ...  Negatif
# 195  196  Beli token listrik 2 kali transaksi di hari yg...  Negatif
# 24    25  Selama belanja di bukalapak alhamdulillah aman...  Positif

# %%
data.describe()
# Out:
#                ID
# count  303.000000
# mean   152.000000
# std     87.612784
# min      1.000000
# 25%     76.500000
# 50%    152.000000
# 75%    227.500000
# max    303.000000

# %%
data.columns
# Out:
# Index(['ID', 'Ulasan', 'Kelas'], dtype='object')

# %%
data['Kelas'].value_counts()
# Out:
# Positif    152
# Negatif    151
# Name: Kelas, dtype: int64

# %% [markdown]
# # Text Preproccessing

# %%
import re
import string

#This function converts to lower-case, removes square bracket, removes numbers and punctuation
def text_clean_1(text):
    #Case Folding
    text = text.lower()
    #Remove Punctuation
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

cleaned1 = lambda x: text_clean_1(x)

DataReview = data.Ulasan.apply(cleaned1)
DataReview
# Out:
# 0                               belanja murah  mudah say
# 1      belanja produk digital disini aja gaesss pulsa...
# 2      sering belanja di bukalapak nyaman murah terpe...
# 3                       ecommerce yang mudah utk belanja
# 4      sangat membantu hidup saya   bukalapak panjang...
#                              ...
# 298    sejauh ini gak ada kendala dan masalah serta g...
# 299    luar biasa baru kali ini saya mendapat keuntun...
# 300              jangan sampe ngga belanja pokoknya hehe
# 301                     sudah ngga lemot bagus bukalapak
# 302    saya sangat nyaman belanja di bukalapak hargan...
# Name: Ulasan, Length: 303, dtype: object

# %% [markdown]
# ### Tokenization

# %%
#Tokenization
from nltk.tokenize import word_tokenize

def text_token(text):
    text = [word_tokenize(doc) for doc in text]
    return text

tokenizing = lambda x: text_token(x)

tokenized_docs = tokenizing(DataReview)

print(tokenized_docs)
# Out:
persyaratan', 'untuk', 'mendapatkan', 'komisi', 'lebih', 'di', 'permudah', 'lagi', 'jadi', 'orang', 'biasa', 'bisa', 'jualan', 'untuk', 'e', 'commers', 'nya'], ['saya', 'kasi', 'bintang', 'aman', 'bgt', 'belanja', 'di', 'sini', 'belanja', 'aman'], ['aku', 'suka', 'karena', 'ghauzyutary', 'itu', 'me', 'jadi', 'aku', 'sukaaa', 'banget', 'muach'], ['pustaka', 'abadi', 'alhamdulillah', 'disini', 'saya', 'dapat', 'terjual', 'dgn', 'mudah', 'terima', 'pkasih'], ['baru', 'pertama', 'pake', 'aplikasi', 'ini', 'puas', 'bangetsmoga', 'bisa', 'selalu', 'seperti', 'ini'], ['jual', 'beli', 'nyaman', 'dan', 'terpercaya', 'sentosa', 'tanpa', 'ada', 'gangguan', 'hehe'], ['mantap', 'bl', 'lapak', 'yg', 'bagus', 'mudah', 'aman'], ['bukalapak', 'sangat', 'bagus', 'jangan', 'bikin', 'kecewa', 'pelanggan', 'ya'], ['aplikasiny', 'bermanfaat', 'buat', 'pelapak', 'yang', 'kecil', 'seperti', 'saya', 'thanks'], ['berjodoh', 'di', 'buka', 'lapak', 'jualan', 'saya', 'menemukan', 'jodohnya', 'di', 'sini', 'setelah', 'setahun', 'tidak', 'kunjung', 'laku', 'baru', 'hari', 'upload', 'di', 'bl', 'alhamdulillah', 'langsung', 'ada', 'yg', 'minat', 'transaksi', 'cepat', 'pula', 'terima', 'kasih', 'bukalapak', 'buka', 'jalan', 'buka', 'harapan'], ['semoga', 'install', 'aplikasi', 'ini', 'bagus', 'gak', 'error'], ['i', 'like', 'it', 'so', 'barang', 'yg', 'bisa', 'di', 'jual', 'ahhhh'], ['buka', 'lapak', 'terpercayamantab'], ['aplikasinya', 'ga', 'ribet', 'banyak', 'promonya'], ['bagus', 'pertahankan', 'kualitas ...

# %% [markdown]
# ### Stopword Removal

# %%
#Removing Stopword
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

factory = StopWordRemoverFactory() 
stopwords = factory.create_stop_word_remover()
getstopwords = factory.get_stop_words()

# Kalimat Contoh
kalimat = 'Dengan Menggunakan Python dan Library Sastrawi saya dapat melakukan proses Stopword Removal'
stop = stopwords.remove(kalimat)
# print(stop)
# print(getstopwords)

# Mulai
tokenized_docs_no_stopwords = []

for doc in tokenized_docs:
    new_term_vector = []
    for word in doc:
        if not word in getstopwords:
            new_term_vector.append(word)
    
    tokenized_docs_no_stopwords.append(new_term_vector)
    
print(tokenized_docs_no_stopwords)
# Out:
# [['belanja', 'murah', 'mudah', 'say'], ['belanja', 'produk', 'digital', 'disini', 'aja', 'gaesss', 'pulsa', 'token', 'listrik', 'tiket', 'pesawattermurah', 'se', 'ol', 'shop'], ['sering', 'belanja', 'bukalapak', 'nyaman', 'murah', 'terpercaya', 'ngga', 'sreg', 'sma', 'wishlishnya', 'kalo', 'yg', 'udh', 'masukin', 'daftar', 'wishlish', 'suka', 'ngga', 'muncul', 'euy', 'perbaikkin', 'dong'], ['ecommerce', 'm
'bermanfaat', 'buat', 'pelapak', 'kecil', 'thanks'], ['berjodoh', 'buka', 'lapak', 'jualan', 'menemukan', 'jodohnya', 'sini', 'setahun', 'kunjung', 'laku', 'baru', 'hari', 'upload', 'bl', 'alhamdulillah', 'langsung', 'yg', 'minat', 'transaksi', 'cepat', 'terima', 'kasih', 'bukalapak', 'buka', 'jalan', 'buka', 'harapan'], ['semoga', 'install', 'aplikasi', 'bagus', 'gak', 'error'], ['i', 'like', 'it', 'so', 'barang', 'yg', 'jual', 'ahhhh'], ['buka', 'lapak', 'terpercayamantab'], ['aplikasinya', 'ga', 'ribet', 'banyak', 'promonya'], ['bagus', 'pertahankan', 'kualitas', 'semuanya', 'bnykin', 'promo', 'adain', 'cod'], ['trimakasih', 'atas', 'fasilitas', 'diberikan', 'promonya', 'hehe'], ['buka', 'lapak', 'emang', 'kaya', 'diiklan', 'tv', 'hehe'], ['transaksi', 'jadi', 'lebih', 'mudah', 'pakai', 'ecommerce', 'bukalapak'], ['bukalapak', 'my', 'hero', 'aman', 'mudah', 'cepat', 'banyak', 'keuntungan', 'sini', 'mantab', 'thankyou', 'sukses', 'selalu', 'bukalapak'], ['keren', 'enak', 'mncari', 'barangsaya', 'beli', 'alphard', 'sama', 'audi', 'lancar', 'aja', 'tipuan', '☺', 'mksih', 'bukalapak'], ['santai', 'akurat'], ['top', 'membantu' ...

# %% [markdown]
# ### Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# Disini biasanya prosesnya lama.. mohon tunggu

# %%
stem_tokenized_docs_no_stopwords = []

for doc in tokenized_docs_no_stopwords:
    new_term_vector = []
    for word in doc:
        new_term_vector.append(stemmer.stem(word))
        
    stem_tokenized_docs_no_stopwords.append(new_term_vector)

print(stem_tokenized_docs_no_stopwords)
# Out:
# [['belanja', 'murah', 'mudah', 'say'], ['belanja', 'produk', 'digital', 'sini', 'aja', 'gaesss', 'pulsa', 'token', 'listrik', 'tiket', 'pesawattermurah', 'se', 'ol', 'shop'], ['sering', 'belanja', 'bukalapak', 'nyaman', 'murah', 'percaya', 'ngga', 'sreg', 'sma', 'wishlishnya', 'kalo', 'yg', 'udh', 'masukin', 'daftar', 'wishlish', 'suka', 'ngga', 'muncul', 'euy', 'perbaikkin', 'dong'], ['ecommerce', 'mudah', 'utk', 'belanja'], ['sangat', 'bantu', 'hidup', 'bukalapak', 'panjang', 'umur', 'amin'], ['makin', 'banyak', 'terobos', 'terobos', 'nya', 'bukalapak', 'mantap', 'euy'], ['guna', 'aplikasi', 'belanja', 'online', 'pilih', 'kurir', 'lacak', 'mudah', 'kalo', 'saran', 'tambah', 'fitur', 'cicil', 'kartu', 'kredit', 'beli', 'trims', 'bukalapak', 'jaya', 'selalu'], ['suka', 'bangt', 'smoga', 'lancar', 'smuanya'], ['hendak', 'beri', 'tahu', 'jg', 'syarat', 'cara', 'buka', 'lapak', 'belanja', 'on', 'line', 'sistematis', 'praktis', 'mudah', 'dipa', 'ham', 'masyarakat', 'terima', 'kasih'], ['
aya', 'iklan', 'tv', 'hehe'], ['transaksi', 'jadi', 'lebih', 'mudah', 'pakai', 'ecommerce', 'bukalapak'], ['bukalapak', 'my', 'hero', 'aman', 'mudah', 'cepat', 'banyak', 'untung', 'sini', 'mantab', 'thankyou', 'sukses', 'selalu', 'bukalapak'], ['keren', 'enak', 'mncari', 'barangsaya', 'beli', 'alphard', 'sama', 'audi', 'lancar', 'aja', 'tipu', '', 'mksih', 'bukalapak'], ['santai', 'akurat'], ['top', 'bantu', 'dlm', 'belanja', 'butuh', 'apa', 'semua'], ['mantabzz', 'jaya', 'abadi', 'sentosa', 'moga', 'makin', 'maju', 'bukalapak'], ['sy', 'suka', 'bngt', 'pakai', 'bukalapak',  ...

# %% [markdown]
# ### Join Data

# %%
Data_After_Preprocessing = []

for doc in stem_tokenized_docs_no_stopwords:
    text = " ".join(doc)
    Data_After_Preprocessing.append(text)
    
print(Data_After_Preprocessing)
# Out:
# ['belanja murah mudah say', 'belanja produk digital sini aja gaesss pulsa token listrik tiket pesawattermurah se ol shop', 'sering belanja bukalapak nyaman murah percaya ngga sreg sma wishlishnya kalo yg udh masukin daftar wishlish suka ngga muncul euy perbaikkin dong', 'ecommerce mudah utk belanja', 'sangat bantu hidup bukalapak panjang umur amin', 'makin banyak terobos terobos nya bukalapak mantap euy', 'guna aplikasi belanja online pilih kurir lacak mudah kalo saran tambah fitur cicil kartu kredit beli trims bukalapak jaya selalu', 'suka bangt smoga lancar smuanya', 'hendak beri tahu jg syarat cara buka lapak belanja on line sistematis praktis mudah dipa ham masyarakat terima kasih', 'aplikasi kerenpaling responsive banding ecommerce laincuma mungkin bbrp fitur tingkat', 'terimakasih bl sy ajar smk jd bisnis dgn omset per bulan', 'good jadi gila jadi gila bukalapak bikin gila bikin gila sakitttttttt jiwaaaaaa sakittttt jiwa', 'bintang', 'bagus banyak promonya', 'rekomendasi banget', 'layan jual beli online mantab', 'mantap gak salah pilih bukalapak emang cincai', 'lebih murah aman belanja sini', 'bagus selalu simpel layan cs nya ramah', 'mantap dech', 'puas belanja aman nyaman lebih murah tentunyabukalapak puas deh', 'mohon tambah lokasi bayar pdam daerah balikpapan', 'bukalapak barang lebih lengkap aplikasi belanja yg gua download waktu sukses terus bukalapak', 'great thanks so much for yr good services', 'lama belanja bukalapak alhamdulillah aman aman', 'syarat dapat komisi lebih mudah jadi orang biasa jual e commers nya', 'kasi bintang aman bgt belanja sini belanja aman', 'aku suka ghauzyutary me jadi aku sukaaa banget muach', 'pustaka abadi alhamdulillah sini jual dgn mudah terima pkasih', 'baru pertama pake aplikasi puas bangetsmoga selalu', 'jual beli nyaman percaya sentosa ganggu hehe', 'mantap bl lapak yg bagus mudah aman', 'bukalapak sangat bagus jangan bikin kecewa langgan', 'aplikasiny manfaat buat lapak kecil thanks', 'jodoh buka lapak jual temu jodoh sini tahun kunjung laku baru hari upload bl alhamdulillah langsung yg minat transaksi cepat terima kasih bukalapak buka jalan buka harap', 'moga install aplikasi bagus gak error', 'i like it so barang yg jual ahhhh', 'buka lapak terpercayamantab', 'aplikasi ga ribet banyak promonya', 'bagus tahan kualitas semua bnykin promo adain cod', 'trimakasih atas fasilitas beri promonya hehe', 'buka lapak emang kaya iklan tv hehe', 'transaksi jadi lebih mudah pakai ecommerce bukalapak', 'bukalapak my hero aman mudah cepat banyak untung sini mantab thankyou sukses selalu bukalapak', 'keren enak mncari barangsaya beli alphard sama audi lancar aja tipu  mksih bukalapak', 'santai akurat', 'top bantu dlm belanja butuh apa semua', 'mantabzz jaya abadi sentosa moga makin maju bukalapak', 'sy suka bngt pakai bukalapak diskon banyak', 'mantap kirim cepet sampe barang bagus sampe', 'mantaps kirim cepat', 'kayak aplikasi ecom yg paling cepatsalut buat tim kembang', 'cepattepatmantap', 'terima kasih bukalapak lama belanja bukalapak gak pernah ngecewain packing rapicepat sampaibarang sesuai pesan pokok top markotop buat bukalapak', 'jempol dach', 'tahan kan moga amanah', 'sangat bantu kasih bintang banyak deh', 'mantap layan bukalapak nomer satu', 'buka lapak sekarang kirim cepet beda sma belah', 'aplikasi bagus manfaat trus kembang kan aplikasi y jgn mau kalah sama aplikasi tetangga heee', 'bukalapak buat repot belanja keluar', 'familiar mudah operasi sayang tdk searching nama lapak', 'sruput aja gak pake lama langsung belanja dibukalapak', 'bukalapak bagus sekali baju putri duyung nya', 'joss bukalapak emang cincaiiiii hehe', 'bagus tingkat yah layan nya maju lalau', 'tempat belanja lengkap unik semua barang ingin harga jangkau', 'lama muas ribet part laptop perlu sedia', 'lumayan lah belanja jadi ngga ribet tinggal nunggu rumah', 'top manfaat semua umat moga pahala banyak', 'upgradenya bukalapak makin mudah beli jual sukses terus', 'asik diskon terus kagak takut rugi apa wkw', 'the bes ...

# %%
#Removing columns
data.drop(columns = ['ID'], inplace = True)

# %%
data['Preprocessing_Ulasan'] = Data_After_Preprocessing
data.sample(5)
# Out:
#                                                 Ulasan    Kelas  \
# 242        Dah mulai oke lg nih jd bintangnya aq ksh 5  Positif
# 139  bukalapak para pelapak nya banyak gak profesio...  Negatif
# 160  Tolong dibenerkan aplikasinya. Banyak pelapak ...  Negatif
# 109  2 transkaksi pakai gojek grab same day dana ba...  Negatif
# 293  aplikasi yang memudahkan untuk pembelian baran...  Positif
#
#                                   Preprocessing_Ulasan
# 242             dah mulai oke lg nih jd bintang aq ksh
# 139  bukalapak lapak nya banyak gak profesional tra...
# 160              dibenerkan aplikasi banyak lapak tipu
# 109  transkaksi pakai gojek grab same day dana bali...
# 293  aplikasi mudah beli barang bamyak promo tarik ...

# %% [markdown]
# # Membuat Train test

# %% [markdown]
# Setelah melakukan langkah diatas, selanjutnya memisahkan data latih dan data uji untuk memisahkannya, disini menggunakan library sklearn

# %%
from sklearn.model_selection import train_test_split

x=data.Preprocessing_Ulasan
y=data.Kelas

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.05, random_state=5)

# %%
print('Banyak data x_train : ',len(x_train))
print('Banyak data x_test : ',len(x_test))
print('Banyak data y_train : ',len(y_train))
print('Banyak data y_test : ',len(y_test))
# Out:
# Banyak data x_train :  287
# Banyak data x_test :  16
# Banyak data y_train :  287
# Banyak data y_test :  16

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

tvec = TfidfVectorizer()
clf2 = LogisticRegression(solver = "lbfgs")
clf3 = MultinomialNB()

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix

model = Pipeline([('vectorizer',tvec),('classifier',clf3)])
model.fit(x_train, y_train)


predictions = model.predict(x_test)
confusion_matrix(predictions, y_test)
# Out:
# array([[5, 1],
#        [2, 8]], dtype=int64)

# %%
DataTes = []
i = 0

for doc in x_test:
    DataTestingJoin = []
    DataTestingJoin.append(doc)
    DataTestingJoin.append(predictions[i])
    DataTes.append(DataTestingJoin)
    i = i + 1
    
pd.DataFrame(DataTes)
# Out:
#                                                     0        1
# 0   sangat nyaman belanja bukalapak harga murah si...  Positif
# 1   layan konsumen perhati jual barang yg kualitas...  Positif
# 2                        sangat senang guna bukalapak  Positif
# 3        nyesel deh install bukalapak kembaliin kuota  Positif
# 4      lama belanja bukalapak alhamdulillah aman aman  Positif
# 5                 mudah cara belanja mudah cara bayar  Positif
# 6   aplikasi marketplace paling banyak tipu online...  Positif
# 7   awal coba eeehketagihan malah ken belanja teru...  Positif
# 8                                 mantaps kirim cepat  Positif
# 9   jelas selalu ikut serbu seru bukalapak dana se...  Negatif
# 10  bukalapak my hero aman mudah cepat banyak untu...  Positif
# 11  beli token listrik kali transaksi hari yg sama...  Negatif
# 12  berak kebon gua udah tahun thun pake aplikasi ...  Negatif
# 13  top up emoney kok ga masukmasuk padahal dulu l...  Negatif
# 14                              sangat bantu ada dana  Negatif
# 15  padahal udh transferpayahudh konfirmasi lewat ...  Negatif

# %% [markdown]
# ## Model Prediction

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print("Accuracy : ", accuracy_score(predictions, y_test))
print("Precision : ", precision_score(predictions, y_test, average = 'weighted'))
print("Recall : ", recall_score(predictions, y_test, average = 'weighted'))
# Out:
# Accuracy :  0.8125
# Precision :  0.8234126984126984
# Recall :  0.8125

# %%
example = ["Aplikasi error"]
result = model.predict(example)

print(result)
# Out:
# ['Negatif']

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix

model = Pipeline([('vectorizer',tvec),('classifier',clf3)])
model.fit(x_train, y_train)


predictions = model.predict(x_test)
confusion_matrix(predictions, y_test)

# %% [markdown]
# ## Mencoba memakai Regression Logistic

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix

model2 = Pipeline([('vectorizer',tvec),('classifier',clf2)])
model2.fit(x_train, y_train)


predictions2 = model2.predict(x_test)
confusion_matrix(predictions, y_test)
# Out:
# array([[5, 0],
#        [2, 9]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print("Accuracy : ", accuracy_score(predictions2, y_test))
print("Precision : ", precision_score(predictions2, y_test, average = 'weighted'))
print("Recall : ", recall_score(predictions2, y_test, average = 'weighted'))
# Out:
# Accuracy :  0.875
# Precision :  0.9107142857142857
# Recall :  0.875
